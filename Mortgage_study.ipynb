# %%
from manager import full_simulation

# %%
# simulation_params
n_months = 360
n_months_left = 339
amount = 150000
best_fixed_rate = 0.0135
worst_fixed_rate = 0.03

n_simulations = 2000
differential = -0.005

# %%
full_simulation(n_months, n_months_left, amount, n_simulations, 
                differential, best_fixed_rate, worst_fixed_rate)
